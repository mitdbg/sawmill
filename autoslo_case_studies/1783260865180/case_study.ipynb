# %%
import autoslo.filesystem.path_utils as pu
from autoslo.filesystem.logos_export import logos_df
from autoslo.filesystem.structured_log import StructuredLog
from autoslo.slo.slo_resolver import SloResolver
from autoslo.config.component_configs import SloResolverConfig
from autoslo.filesystem.yaml_helpers import load_yaml
from logos import Logos
from IPython.display import Image

# %%
RUN_ID = "1783276972704"

# %%
log = StructuredLog.load(RUN_ID)

# %%
log.query_latencies()
# Out:
#      query_id          query_text_id     arrival_s  completion_s  latency_s  \
# 0      128047  ext_tpcds1000#009#001   4248.981604   4263.110564     14.129
# 1      128105  ext_tpcds1000#028#001   4511.163242   4544.071575     32.908
# 2      128106  ext_tpcds1000#028#001   6882.762290   6978.035577     95.273
# 3      128136  ext_tpcds1000#009#001  12580.892927  12611.091063     30.198
# 4      128137  ext_tpcds1000#009#002  13139.536913  13155.978463     16.442
# ...       ...                    ...           ...           ...        ...
# 1351   202001  ext_tpcds1000#052#001   6891.779845   6893.951474      2.172
# 1352   202023  ext_tpcds1000#028#003   7163.339688   7192.849391     29.510
# 1353   202066  ext_tpcds1000#028#001   8383.998926   8403.529938     19.531
# 1354   202090  ext_tpcds1000#009#003   5656.643872   5682.845542     26.202
# 1355   202115  ext_tpcds1000#028#003   9562.373273   9632.932577     70.559
#
#       latency_prediction_at_arrival_s
# 0                           32.621956
# 1                           18.329987
# 2                           19.119520
# 3                           29.218021
# 4                           30.013458
# ...                               ...
# 1351                         0.862235
# 1352                        21.358484
# 1353                        18.371414
# 1354                        28.778955
# 1355                        23.217731
#
# [1356 rows x 6 columns]

# %%
exec_cfg = load_yaml(pu.get_runs_dir() / RUN_ID / "execution_config.yml")
resolver = SloResolver(
    SloResolverConfig(
        slo_s=exec_cfg["slo_resolver_config"]["slo_s"],
        slo_dict_filename=exec_cfg["slo_resolver_config"]["slo_dict_filename"],
    )
)
df = logos_df(
    run_id=RUN_ID,
    slo_resolver=resolver,
    drop_fwd_queries=True,
    include_named_query_features=True,
    include_overlap_counts=True,
)
# Out:
# Loading model checkpoint from /home/markakis/chunkbench/data/iconq_models/model_v8/model_1782160265.pth

# %%
df.shape
# Out:
# (17399, 91)

# %%
per_query_id_constant_cols = [
    c for c in df.columns if df.groupby("query_id")[c].nunique().max() == 1
]

lg = Logos.from_parsed_table(
    data=df,
    workdir=".",
    source_id="structured_log_p40",
    template_col="event_type",
    passthrough_cols=["wall_clock_s", "rel_time_s"],
    per_unit_cols=per_query_id_constant_cols,
)

# %%
lg.set_causal_unit("query_id")

# %%
lg.prepare(
    default_imp="zero_imp",
    force=True,
    custom_agg={
        "latency_update updated_predicted_latency_over_slo": ["last"],
    },
)
# Out:
# Imputing missing values...:   0%|          | 0/268 [00:00<?, ?it/s]
# One-hot encoding categorical variables...:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
lg.rank_candidate_causes("observed_slo_violation mean")
# Out:
#          Candidate                   Candidate Tag  \
# 0  c9db7d03_0+mean         observed_latency_s mean
# 1  17a1a008_0+mean  observed_latency_over_slo mean
#
#                     Target Tag     Slope        P-value  \
# 0  observed_slo_violation mean  0.004617  1.978674e-133
# 1  observed_slo_violation mean  0.111680  5.650976e-125
#
#   Candidate->Target Edge Status Target->Candidate Edge Status
# 0                     Undecided                     Undecided
# 1                     Undecided                     Undecided

# %%
lg.accept("observed_latency_over_slo mean", "observed_slo_violation mean")
lg.rank_candidate_causes("observed_latency_over_slo mean")
# Out:
#                                 Candidate  \
# 0                         f1db3404_0+mean
# 1                         3609b411_3+last
# 2                         c9db7d03_0+mean
# 3                         4dcd0ef6_0+mean
# 4                         0a2e608e_0+mean
# 5                         9b468fb9_0+mean
# 6                         99854374_0+mean
# 7   28f4a0f8_0+last=ext_tpcds1000#020#003
# 8                         ebdcf81f_2+mean
# 9                         3609b411_2+mean
# 10                        f45d4049_0+mean
#
#                                         Candidate Tag  \
# 0                            num_active_at_start mean
# 1   latency_update updated_predicted_latency_over_...
# 2                             observed_latency_s mean
# 3             initial_predicted_latency_over_slo mean
# 4                                 XN Merge#count mean
# 5        XN Hash Join DS_BCAST_INNER#cardinality mean
# 6                                          slo_s mean
# 7            query_text_id last ext_tpcds1000#020#003
# 8            routing_score latency_s_for_routing mean
# 9                   latency_update old_latency_s mean
# 10                           arrival_rate_during mean
#
#                         Target Tag     Slope        P-value  \
# 0   observed_latency_over_slo mean  0.203027  1.799113e-101
# 1   observed_latency_over_slo mean  0.826742   1.295302e-58
# 2   observed_latency_over_slo mean  0.015155   6.566942e-47
# 3   observed_latency_over_slo mean  3.571062   1.226155e-32
# 4   observed_latency_over_slo mean  0.729998   6.704418e-17
# 5   observed_latency_over_slo mean  0.035792   2.268088e-16
# 6   observed_latency_over_slo mean -0.005696   3.448348e-13
# 7   observed_latency_over_slo mean  1.941414   1.452165e-07
# 8   observed_latency_over_slo mean -0.020611   2.206539e-07
# 9   observed_latency_over_slo mean  0.002969   2.188859e-01
# 10  observed_latency_over_slo mean -0.071395   3.885552e-01
#
#    Candidate->Target Edge Status Target->Candidate Edge Status
# 0                      Undecided                     Undecided
# 1                      Undecided                     Undecided
# 2                      Undecided                     Undecided
# 3                      Undecided                     Undecided
# 4                      Undecided                     Undecided
# 5                      Undecided                     Undecided
# 6                      Undecided                     Undecided
# 7                      Undecided                     Undecided
# 8                      Undecided                     Undecided
# 9                      Undecided                     Undecided
# 10                     Undecided                     Undecided

# %%
lg.accept('num_active_at_start mean', 'observed_latency_over_slo mean')
lg.accept('initial_predicted_latency_over_slo mean', 'observed_latency_over_slo mean')
lg.accept('latency_update updated_predicted_latency_over_slo last', 'observed_latency_over_slo mean')

lg.save_graph("/tmp/g.png") or Image("/tmp/g.png")

# %%
lg.get_adjusted_ate(
    "initial_predicted_latency_over_slo mean", "observed_latency_over_slo mean"
)
# Out:
# 0.5759185050882345

# %%
lg.get_causal_graph_refinement_suggestion(
    "initial_predicted_latency_over_slo mean", "observed_latency_over_slo mean"
)
# Out:
# ('num_active_at_start mean', 'initial_predicted_latency_over_slo mean')

# %%
lg.accept('num_active_at_start mean', 'initial_predicted_latency_over_slo mean')
lg.get_adjusted_ate(
    "initial_predicted_latency_over_slo mean", "observed_latency_over_slo mean"
)
# Out:
# 1.6331464892177125
